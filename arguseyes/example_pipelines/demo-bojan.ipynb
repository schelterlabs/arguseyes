# %%
from arguseyes import ArgusEyes
import logging

logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)

eyes = ArgusEyes('demo-bojan2', '../../mlruns')

# %%
pipeline = eyes.classification_pipeline_from_py_file('./amazon-reviews.py')
# Out:
# INFO:Patching sys.argv with ['eyes']
# INFO:Created run 6de4416c249e4b859bc54f98f6ec3a33 for this invocation
# INFO:Executing instrumented user pipeline with mlinspect
# INFO:Redirecting the pipeline's stdout to arguseyes-pipeline-output.txt
# INFO:Identifying training sources
# INFO:Found dimension table from operator 1 with 10936 records and the following attributes: ['product_id', 'product_parent', 'product_title', 'category_id', 'mlinspect_lineage']
# INFO:Found dimension table from operator 2 with 2 records and the following attributes: ['id', 'category', 'mlinspect_lineage']
# INFO:Found dimension table from operator 3 with 246560 records and the following attributes: ['review_id', 'star_rating', 'helpful_votes', 'total_votes', 'mlinspect_lineage']
# INFO:Found fact table from operator 0 with 246560 records and the following attributes: ['marketplace', 'customer_id', 'review_id', 'product_id', 'vine', 'verified_purchase', 'review_headline', 'review_body', 'review_date', 'mlinspect_lineage']
# INFO:Identifying test sources
# INFO:Found dimension table from operator 1 with 10936 records and the following attributes: ['product_id', 'product_parent', 'product_title', 'category_id', 'mlinspect_lineage']
# INFO:Found dimension table from operator 2 with 2 records and the following attributes: ['id', 'category', 'mlinspect_lineage']
# INFO:Found dimension table from operator 3 with 246560 records and the following attributes: ['review_id', 'star_rating', 'helpful_votes', 'total_votes', 'mlinspect_lineage']
# INFO:Found fact table from operator 0 with 246560 records and the following attributes: ['marketplace', 'customer_id', 'review_id', 'product_id', 'vine', 'verified_purchase', 'review_headline', 'review_body', 'review_date', 'mlinspect_lineage']
# INFO:Extracted feature matrix X_train with 24214 rows and 104 columns
# INFO:Extracted feature matrix X_test with 2861 rows and 104 columns
# INFO:Extracted y_train and y_test

# %%
pipeline.X_train.shape
# Out:
# (24214, 104)

# %%
pipeline.y_test.shape
# Out:
# (2861, 1)

# %%
for train_source in pipeline.train_sources:
    print(train_source.source_type, train_source.data.columns)
# Out:
# SourceType.DIMENSION Index(['product_id', 'product_parent', 'product_title', 'category_id',
#        'mlinspect_lineage'],
#       dtype='object')
# SourceType.DIMENSION Index(['id', 'category', 'mlinspect_lineage'], dtype='object')
# SourceType.DIMENSION Index(['review_id', 'star_rating', 'helpful_votes', 'total_votes',
#        'mlinspect_lineage'],
#       dtype='object')
# SourceType.FACTS Index(['marketplace', 'customer_id', 'review_id', 'product_id', 'vine',
#        'verified_purchase', 'review_headline', 'review_body', 'review_date',
#        'mlinspect_lineage'],
#       dtype='object')

# %%
pipeline.train_sources[3].data
# Out:
#        marketplace  customer_id       review_id  product_id vine  \
# 0               US     21269168   RSH1OZ87OYK92  B013PURRZW    N
# 1               US       133437  R1WFOQ3N9BO65I  B00F4CEHNK    N
# 2               US     45765011   R3YOOS71KM5M9  B00DNHLFQA    N
# 3               US       113118  R3R14UATT3OUFU  B004RMK5QG    N
# 4               US     22151364   RV2W9SGDNQA2C  B00G9BNLQE    N
# ...            ...          ...             ...         ...  ...
# 246555          US     41754720  R19OFJV91M7D8X  B000YMR61A    N
# 246556          US     51669529  R1I6G894K5AGG5  B000YMR61A    N
# 246557          US     24731012  R17OE43FFEP81I  B000YMR5X4    N
# 246558          US     16049580  R15MGDDK63B52Z  B000YMR61A    N
# 246559          US     46098046  R1GGJJA2R68033  B000YMNI2Q    N
#
#        verified_purchase                                    review_headline  \
# 0                      N               A slight improvement from last year.
# 1                      Y                                         Five Stars
# 2                      Y                            Hail to the great Yuri!
# 3                      Y                                         Five Stars
# 4                      Y                                         Five Stars
# ...                  ...                                                ...
# 246555                 N           Easy to use, 1 comment 1 serious problem
# 246556                 N  Schedule C  IS for business- figures it would ...
# 246557                 N                                 Hassel to download
# 246558                 N                                    beware of vista
# 246559                 N                             don't waste your money
#
#                                               review_body review_date  \
# 0       I keep buying madden every year hoping they ge...  2015-08-31
# 1                                                 Awesome  2015-08-31
# 2       If you are prepping for the end of the world t...  2015-08-31
# 3                                                 Perfect  2015-08-31
# 4                                                Awesome!  2015-08-31
# ...                                                   ...         ...
# 246555  I chose the deluxe version CD because of mortg...  2008-02-11
# 246556  Schedule C  IS for business, so figures it wou...  2008-02-08
# 246557  I wish that companies can test several scenari...  2008-02-05
# 246558  i just installed turbotax deluxe 2007. If you ...  2008-02-05
# 246559  The description mentions that you can use this...  2008-01-26
#
#                                 mlinspect_lineage
# 0            {LineageId(operator_id=0, row_id=0)}
# 1            {LineageId(operator_id=0, row_id=1)}
# 2            {LineageId(operator_id=0, row_id=2)}
# 3            {LineageId(operator_id=0, row_id=3)}
# 4            {LineageId(operator_id=0, row_id=4)}
# ...                                           ...
# 246555  {LineageId(operator_id=0, row_id=246555)}
# 246556  {LineageId(operator_id=0, row_id=246556)}
# 246557  {LineageId(operator_id=0, row_id=246557)}
# 246558  {LineageId(operator_id=0, row_id=246558)}
# 246559  {LineageId(operator_id=0, row_id=246559)}
#
# [246560 rows x 10 columns]

# %%
from arguseyes.issues import LabelShift

pipeline.detect_issue(LabelShift())
# Out:
# Issue(id='label_shift', is_present=False, details={'threshold': 0.01, 'p_value': 0.012333776748022897})

# %%
from arguseyes.issues import TrainTestOverlap

pipeline.detect_issue(TrainTestOverlap())
# Out:
# Issue(id='traintest_overlap', is_present=False, details={'num_overlapping_records': 0})

# %%
from arguseyes.refinements import DataValuation

valued_source = pipeline.compute(DataValuation())

# %%
valued_source.data.sort_values(by='__arguseyes__shapley_value')
# Out:
#       marketplace  customer_id       review_id  product_id vine  \
# 6623           US     32645745   ROMK0DESUAGXM  B00F4CEOS8    N
# 22267          US      1873730  R1GTSX1T67W9VT  B00F4CEWOY    N
# 13206          US      4884720  R3LKV31LDXZ80E  B00F4CFBUS    N
# 6103           US     51193051   RLW7D0JVKSTFW  B00R6HA3XY    N
# 5727           US     37240099   R4B0L5TUQJHNM  B00F4CEWOY    N
# ...           ...          ...             ...         ...  ...
# 28463          US      6762254  R21ADNR2NHLKXO  B00F4CF39C    N
# 17084          US      1078691   RU9CMHFAHGLA6  B00F4CF4PU    N
# 27490          US     12907607   RJ50WZWSQURCI  B001KC03ZE    N
# 10525          US     12355424  R1GDH9VAISUPMZ  B007TY85PC    N
# 24330          US     19815996  R1PW808R3ZI91M  B007TY84MG    N
#
#       verified_purchase                                    review_headline  \
# 6623                  Y                                             Bummer
# 22267                 Y                                         Five Stars
# 13206                 Y                                           One Star
# 6103                  Y  I don't know why, but this game is totally awe...
# 5727                  Y                                         Easy Peasy
# ...                 ...                                                ...
# 28463                 Y                                    said it was use
# 17084                 Y
# 27490                 Y                                       A Great Game
# 10525                 Y                                              Great
# 24330                 Y                                         Five Stars
#
#                                              review_body review_date  \
# 6623                      You can't use this 4 xbox live  2015-06-30
# 22267                                           It works  2015-02-16
# 13206                                        Didn't come  2015-04-26
# 6103   First of all, I want to admit that I am a Mort...  2015-07-06
# 5727   Quick and simple; it beats the heck out of hav...  2015-07-09
# ...                                                  ...         ...
# 28463                                         didnt work  2015-01-05
# 17084  I bought this for an Xbox live deal but you ca...  2015-03-25
# 27490  I like Jewel Quest III, although not as well a...  2015-01-11
# 10525                                              Great  2015-05-23
# 24330                                  Very challenging!  2015-02-03
#
#                               mlinspect_lineage  __arguseyes__shapley_value
# 6623    {LineageId(operator_id=0, row_id=6623)}                   -0.081228
# 22267  {LineageId(operator_id=0, row_id=22267)}                   -0.015819
# 13206  {LineageId(operator_id=0, row_id=13206)}                   -0.014562
# 6103    {LineageId(operator_id=0, row_id=6103)}                   -0.011098
# 5727    {LineageId(operator_id=0, row_id=5727)}                   -0.011067
# ...                                         ...                         ...
# 28463  {LineageId(operator_id=0, row_id=28463)}                    0.018728
# 17084  {LineageId(operator_id=0, row_id=17084)}                    0.018728
# 27490  {LineageId(operator_id=0, row_id=27490)}                    0.022424
# 10525  {LineageId(operator_id=0, row_id=10525)}                    0.022432
# 24330  {LineageId(operator_id=0, row_id=24330)}                    0.022436
#
# [246560 rows x 11 columns]

# %%
from mlinspect.inspections._inspection_input import OperatorType
from arguseyes.utils.dag_extraction import find_dag_node_by_type

dag_node_to_lineage_df = pipeline.dag_node_to_lineage_df
features_op = find_dag_node_by_type(OperatorType.TRAIN_DATA, dag_node_to_lineage_df.keys())
dag_node_to_lineage_df[features_op]
# Out:
#                                                    array  \
# 0      [-2.047682888564837, 1.0, 1.0, 1.0, 0.20412414...
# 1      [0.635357883280886, 1.0, 1.0, 1.0, 0.0, 0.0, 0...
# 2      [0.635357883280886, 1.0, 1.0, 1.0, 0.0, 0.0, 0...
# 3      [0.635357883280886, 1.0, 1.0, 1.0, 0.0, 0.0, 0...
# 4      [0.635357883280886, 1.0, 1.0, 1.0, 0.088388347...
# ...                                                  ...
# 24209  [0.635357883280886, 1.0, 1.0, 1.0, 0.0, -0.182...
# 24210  [-2.047682888564837, 1.0, 1.0, 1.0, 0.0, 0.0, ...
# 24211  [-0.03540230968054473, 1.0, 1.0, 1.0, 0.0, -0....
# 24212  [-0.7061625026419754, 1.0, 1.0, 1.0, 0.0, 0.17...
# 24213  [-2.047682888564837, 1.0, 1.0, 1.0, 0.0, -0.14...
#
#                                        mlinspect_lineage
# 0      {LineageId(operator_id=3, row_id=3193), Lineag...
# 1      {LineageId(operator_id=1, row_id=1), LineageId...
# 2      {LineageId(operator_id=2, row_id=0), LineageId...
# 3      {LineageId(operator_id=1, row_id=1), LineageId...
# 4      {LineageId(operator_id=2, row_id=0), LineageId...
# ...                                                  ...
# 24209  {LineageId(operator_id=1, row_id=3943), Lineag...
# 24210  {LineageId(operator_id=2, row_id=0), LineageId...
# 24211  {LineageId(operator_id=2, row_id=0), LineageId...
# 24212  {LineageId(operator_id=2, row_id=0), LineageId...
# 24213  {LineageId(operator_id=3, row_id=29436), Linea...
#
# [24214 rows x 2 columns]

# %%
import mlflow
mlflow.end_run()
